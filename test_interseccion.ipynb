# %%
from Point import Point
from Segment import Segment
import Funciones as F
import matplotlib.pyplot as plt

# %%
p1 = Point(1, 2)
p2 = Point(1, 0)
p3 = Point(0, 1)
p4 = Point(2, 1)

s1 = Segment(p1, p2)
s2 = Segment(p3, p4)

# %%
F.on_segment(p1, p2, p3)
# Out:
# False

# %%
F.direction(p1, p3, p2)
# Out:
# -2

# %%
F.segments_intersect(s1, s2)
# Out:
# True

# %%
cruce = F.punto_de_cruce(s1, s2)

s1.dibujar("s1")
s2.dibujar("s2")
plt.scatter([cruce.x], [cruce.y])
plt.legend()

# %%
p1 = Point(0, 0)
p2 = Point(2, 2)
p3 = Point(3, 2)
p4 = Point(1, 1)

s1 = Segment(p1, p2)
s2 = Segment(p3, p4)

# %%
F.on_segment(p1, p2, p4)
# Out:
# True

# %%
F.segments_intersect(s1, s2)
# Out:
# True

# %%
cruce = F.punto_de_cruce(s1, s2)

s1.dibujar("s1")
s2.dibujar("s2")
plt.scatter([cruce.x], [cruce.y])
plt.legend()

# %%
p1 = Point(0, 0)
p2 = Point(2, 2)
p3 = Point(3, 2)
p4 = Point(1, 0.5)

s1 = Segment(p1, p2)
s2 = Segment(p3, p4)

s1.dibujar("s1")
s2.dibujar("s2")
plt.legend()

# %%
F.segments_intersect(s1, s2)
# Out:
# False

# %%
p1 = Point(1, 2)
p2 = Point(0, 0)
p3 = Point(0, 1)
p4 = Point(2, 1)

s1 = Segment(p1, p2)
s2 = Segment(p3, p4)

cruce = F.punto_de_cruce(s1, s2)

s1.dibujar("s1")
s2.dibujar("s2")
plt.scatter([cruce.x], [cruce.y])
plt.legend()
